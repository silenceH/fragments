# %%
from rdkit import Chem
from rdkit.Chem import AllChem, BRICS, Draw, rdShapeHelpers, Descriptors, PyMol
from rdkit.Chem.Draw import IPythonConsole

# %%
suppl = Chem.SDMolSupplier('/usr/users/people/matts/fragments/test_output/cpp/group_0.sdf')
mols = [x for x in suppl if x is not None]
for m in mols:
    tmp = AllChem.Compute2DCoords(m)

# %%
Draw.MolsToGridImage(mols)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x2F37488>
